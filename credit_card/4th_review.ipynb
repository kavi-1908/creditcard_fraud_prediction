# %% [markdown]
# # Credict Card Fraud detection

# %%
import numpy as np 
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import BaggingClassifier
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix

# %%
cd = pd.read_csv('creditcard.csv')
cd.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
cd.shape

# %%
cd['Class'].value_counts()

# %%
# Step 1: Split the dataset into two separate DataFrames
df_class_0 = cd[cd['Class'] == 0]
df_class_1 = cd[cd['Class'] == 1]

# Step 2: Balancing the classes (if needed)
sample_size = min(len(df_class_0), len(df_class_1))

# Sample from each class with replacement to achieve the desired sample size
df_class_0_sampled = df_class_0.sample(n=sample_size, replace=True, random_state=42)
df_class_1_sampled = df_class_1.sample(n=sample_size, replace=True, random_state=42)

# Step 3: Combine the sampled dataframes
sampled_df = pd.concat([df_class_0_sampled, df_class_1_sampled])

# Step 4: Shuffle the final dataset
cd = sampled_df.sample(frac=1, random_state=42)

# %%
x = cd.drop(columns='Class',axis=1)
y = cd['Class']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.1,stratify=y,random_state=2)

# %%
classifiers = [
    RandomForestClassifier(random_state=42),
    LogisticRegression(random_state=42),
    KNeighborsClassifier(),
    GradientBoostingClassifier(random_state=42),
    GaussianNB(),
    SVC(kernel='linear', random_state=42),
    DecisionTreeClassifier(random_state=42),
    MLPClassifier(random_state=42),
    AdaBoostClassifier(random_state=42),
    BaggingClassifier(random_state=42)
]

# Loop through each classifier
for classifier in classifiers:
    classifier_name = classifier.__class__.__name__

    # Fit the classifier to the training data
    classifier.fit(x_train, y_train)

    # Predict on the test data
    y_pred = classifier.predict(x_test)

    # Calculate Accuracy , precision , recall  and F1-score
    accuracy =accuracy_score(y_test,y_pred)
    precision = precision_score(y_test, y_pred, average='weighted')
    recall = recall_score(y_test, y_pred, average='weighted')
    f1 = f1_score(y_test, y_pred, average='weighted')

    # Calculate support
    class_support = np.unique(y_test, return_counts=True)[1]

    # Calculate confusion matrix
    cm = confusion_matrix(y_test, y_pred)

    # Print metrics
    
    print(f"Metrics for {classifier_name}:")
    print(f"Accuracy Score {accuracy}")
    print(f"Precision: {precision:.2f}")
    print(f"Recall: {recall:.2f}")
    print(f"F1-score: {f1:.2f}")
    print(f"Support: {class_support}")
    # print("Confusion Matrix:")
    # print(cm)
    
    # Plot confusion matrix as a heatmap
    plt.figure(figsize=(2, 2))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.xlabel("Predicted")
    plt.ylabel("True")
    plt.title(f"Confusion Matrix for {classifier_name}")
    plt.show()
    
    print("="*50)
# Out:
# Metrics for RandomForestClassifier:
# Accuracy Score 0.98989898989899
# Precision: 0.99
# Recall: 0.99
# F1-score: 0.99
# Support: [50 49]
# Confusion Matrix:
# [[49  1]
#  [ 0 49]]
# ...
# Metrics for LogisticRegression:
# Accuracy Score 0.9191919191919192
# Precision: 0.92
# Recall: 0.92
# F1-score: 0.92
# Support: [50 49]
# Confusion Matrix:
# [[46  4]
#  [ 4 45]]
# ...
# Metrics for KNeighborsClassifier:
# Accuracy Score 0.6666666666666666
# Precision: 0.67
# Recall: 0.67
# F1-score: 0.67
# Support: [50 49]
# Confusion Matrix:
# [[31 19]
#  [14 35]]
# ...
# Metrics for GradientBoostingClassifier:
# Accuracy Score 0.9797979797979798
# Precision: 0.98
# Recall: 0.98
# F1-score: 0.98
# Support: [50 49]
# Confusion Matrix:
# [[48  2]
#  [ 0 49]]
# ...
# Metrics for GaussianNB:
# Accuracy Score 0.898989898989899
# Precision: 0.90
# Recall: 0.90
# F1-score: 0.90
# Support: [50 49]
# Confusion Matrix:
# [[48  2]
#  [ 8 41]]
# ...
# Metrics for SVC:
# Accuracy Score 0.9595959595959596
# Precision: 0.96
# ...
